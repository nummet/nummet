# %% [markdown]
# # Kapittel 4

# %%
"""Dette skriptet plottar tre funksjonar."""

# Importerer bibliotek
import numpy as np
import matplotlib.pyplot as plt

# Vektor med argumentverdiar
x = np.linspace(-5, 7, 500)
# Vektorar med funksjonsverdiar
y = np.sin(np.exp(x))
z = np.exp(np.sin(x))
f = np.cos(np.exp(x))

# Plottar funksjonane saman
plt.plot(x, y, 'b-')
plt.plot(x, z, 'r-')
plt.plot(x, f, 'g-')
plt.show()

# %%
"""Skript som finn løysingane av andregradslikninga,
a x^2 + b x + c = 0.
Koeffisientane a, b og c blir lest inn frå skjerm.
"""

# Importerer NumPy-biblioteket
import numpy as np

# Les inn koeffisientane
a = float(input('Gi verdien for a: '))
b = float(input('Gi verdien for b: '))
c = float(input('Gi verdien for c: '))

# Reknar ut løysingane
x1 = (-b-np.sqrt(b**2-4*a*c))/(2*a)
x2 = (-b+np.sqrt(b**2-4*a*c))/(2*a)

# Skriv løysingane til skjerm
print(f'x1 = {x1}')
print(f'x2 = {x2}')
# Out:
# Gi verdien for a:  1
# Gi verdien for b:  -2
# Gi verdien for c:  -4
# x1 = -1.2360679774997898
# x2 = 3.23606797749979

# %%
"""Skript som reknar ut kva eit beløp i NOK tilsvarar i
pund, euro og svenske kroner. Dei aktuelle kursane er
fiksert i skriptet.
"""

# Kursar
kurs_euro = 11.50
kurs_pund = 12.81
kurs_SVK = 101.30/100

# Les inn beølp i NOK:
NOK = float(input('Beløp i norske kroner: '))

# Resultat
belop_euro = NOK/kurs_euro
belop_pund = NOK/kurs_pund
belop_SVK = NOK/kurs_SVK
# Skriv resultata til skjerm
print(f'Beløp i euro: {belop_euro}')
print(f'Beløp i pund: {belop_pund}')
print(f'Beløp i svenske kroner: {belop_SVK}')
# Out:
# Beløp i norske kroner:  153
# Beløp i euro: 13.304347826086957
# Beløp i pund: 11.943793911007026
# Beløp i svenske kroner: 151.0365251727542

# %%
"""Skript som les inn eit tal og avgjer om talet er
positivt eller negativt, om det er eit heiltal eller
ikkje og - dersom det er eit heiltal - om det er eit
partal eller eit oddetal
"""

# Les inn tal frå kommandovindauga
x = float(input('Gi eit tal: '))

# Avgjer om talet er positivt eller negativt
if x<0:
    print('Talet er negativt')
else:
    print('Talet er positivt eller null')

# Avgjer om talet er eit heiltal
if round(x)!=x:
     print('Talet er ikkje eit heiltal')
else:
    # Avgjer om talet er eit partal
    if round(x/2)==x/2:
        print('Talet er eit partal')
    else:
        print('Talet er eit oddetal')
# Out:
# Gi eit tal:  10
# Talet er positivt eller null
# Talet er eit partal

# %%
"""Dette skriptet løyser likninga 
a x^2 + b x + c = 0 .
Vi er her berre interesserte i reelle løysingar.
Dersom der berre er ei løysing, blir denne skriven til
skjerm ein gong.
"""

# Importerer NumPy
import numpy as np

# Les inn verdiane for a, b og c:
a = float(input('Gi verdien for a: '))
b = float(input('Gi verdien for b: '))
c = float(input('Gi verdien for c: '))

# Ser om det er ei førstegradslikning
if a==0:
    if b==0:
        print('Inga løysing')
    else:      
        x = -c/b
        print(f'x = {x:.5f}')

# Undersøker om vi har to, ei eller ingen reelle løysingar
elif b**2-4*a*c<0:              # Inga reell løysing
    print('Inga reell løysing')
elif b**2-4*a*c==0:             # Ei løysing
    x = -b/(2*a)
    print(f'x = {x:.5f}')
else:                           # To løysingar
    x1 = (-b-np.sqrt(b**2-4*a*c))/(2*a)
    x2 = (-b+np.sqrt(b**2-4*a*c))/(2*a)
    print(f'x1 = {x1:.5f}')
    print(f'x2 = {x2:.5f}')
# Out:
# Gi verdien for a:  0
# Gi verdien for b:  1
# Gi verdien for c:  2
# x = -2.00000

# %%
# Bibliotek
import numpy as np
import matplotlib.pyplot as plt

# Definerer funksjonen
def funk(x):
    return x**2*np.cos(x)

# Reknar ut nokre funksjonsverdiar og skriv dei til skjerm
x1 = 0
funk_val_1 = funk(x1)
x2 = np.pi
funk_val_2 = funk(x2)
print(f'For x = {x1:.4f} er f(x) = {funk_val_1:.4f}')
print(f'For x = {x2:.4f} er f(x) = {funk_val_2:.4f}')
 
# Plottar funksjonen for eit sett med x-verdiar
x = np.linspace(-6, 6, 1000)
f = funk(x)
plt.plot(x, f)
plt.show()
# Out:
# For x = 0.0000 er f(x) = 0.0000
# For x = 3.1416 er f(x) = -9.8696

# %%
def delt_forskrift(x):
    """Funksjon med delt forskrift."""
    if x<2:
      f = np.cos(np.pi*x)+2
    else:
      f = x**2-2
    return f

# %%
def delt_forskrift(x):
    """Funksjon med delt forskrift som kan kallast med vektor-argument."""
    return (x<2) * (np.cos(np.pi*x)+2) + \
           (x>=2) * (x**2-2)
